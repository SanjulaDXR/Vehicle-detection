# %%
import os
import cv2
import joblib
import numpy as np
from skimage import feature
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay,classification_report

img = cv2.imread('2.png')  #Read vehicle image
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) #Converting previous image to GRAY
plt.imshow(img,cmap='gray')
print(img.shape) #imamge size 64 x 64 pixels
# Out:
# (64, 64)

# %%
from sklearn.metrics import classification_report

print(classification_report(test_target,predicted_target,target_names=['vehicle', 'non-vehicle']))

# %%
hog_vector,hog_img = feature.hog(img,visualize=True) #Get hog feature vector and hog image using skimage feature library
plt.imshow(hog_img,cmap='gray') #Corresponding HOG image to input image
print(hog_img.shape) #Get the size of hog Image
print(hog_vector.shape) #Get the size of hog vector
# Out:
# (64, 64)
# (2916,)

# %%
data_path=r'D:\4TH YEAR\REserch\DATA SET\archive\data' #Data set path (vehicle and non-vehicle images)
categories=os.listdir(data_path) #category types in the dataset (vehicle and non-vehicle)
print(categories)
labels=np.arange(len(categories)) #train folder contain two categories vehicle and non vehicle
print(labels) #in those folder, corresponding images are stored
label_dict=dict(zip(categories,labels)) #non vehicle as 0 and vehicle as 1
print(label_dict)
# Out:
# ['non-vehicles', 'vehicles']
# [0 1]
# {'non-vehicles': 0, 'vehicles': 1}

# %%
img_size=64 
data=[] #Define array to store images
target=[] #Define array to store images class

for category in categories:  #Creating a function to run the below process through the selected folders
    
    imgs_path=os.path.join(data_path,category) #Select a folder and run below funtion through the images in the folder(vehicle and non-vehicle)
    img_names=os.listdir(imgs_path)
    print(imgs_path)
    
    for img_name in img_names: #apply preprocessing to data in dataset
        
        img_path=os.path.join(imgs_path,img_name) #select image by image in the folder
        print(img_path)
        try:
            img=cv2.imread(img_path) #Read images in selected folder
            img=cv2.resize(img,(img_size,img_size)) #Resize the image before applying any filters
            gray1 = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) #Converting the image to GRAY because colour is not a feature to a vehicle
            gray = cv2.GaussianBlur(gray1,(5,5),2.0) #Add GaussianBlur to reduce noise in image
            data.append(gray) #Append those images to data predefined array
            target.append(label_dict[category]) #Append previous image category into target predefined array
           
        except Exception as e:
            print(img_path,e)
# Out:
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra10.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra100.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1000.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1001.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1002.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1003.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1004.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1005.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1006.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1007.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1008.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1009.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra101.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1010.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1011.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1012.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1013.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1014.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1015.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra102.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra103.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1032.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1033.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1034.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1035.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1036.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1037.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1038.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1039.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra104.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1040.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1041.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1042.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1043.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1044.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1045.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1046.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1047.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1048.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1049.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra105.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1050.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1051.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1052.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1053.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1054.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1055.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1056.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1057.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1058.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1059.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra106.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1060.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1061.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1062.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1063.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1064.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1065.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1066.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1067.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1068.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra107.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra108.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1089.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra109.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1090.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1091.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1092.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1093.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1094.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1095.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1096.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1097.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1098.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1099.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra11.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra110.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1100.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1101.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1102.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1103.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1104.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1105.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1106.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1107.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1108.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1109.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1110.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1111.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1112.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1113.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1114.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1115.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1116.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1117.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1118.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1119.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra112.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1120.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1121.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1122.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1123.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1124.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra113.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra114.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1146.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1147.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1148.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1149.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra115.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra1150.png
# D:\4TH YEAR\REserch\DATA SET\archive\data\non-vehicles\extra
png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (603).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (604).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (605).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (606).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (607).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (608).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (609).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (61).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (610).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (611).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (612).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (613).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (614).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (615).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (616).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (617).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (618).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (619).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (62).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (620).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (621).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (622).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (623).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (624).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (625).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (626).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (627).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (628).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (629).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (63).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (630).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (631).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (632).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (633).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (634).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (635).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (636).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (637).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (638).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (639).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (64).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (640).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (641).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (642).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (643).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (644).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (645).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (646).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (647).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (648).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (649).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (65).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (650).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (651).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (652).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (653).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (654).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (655).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (656).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (657).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (658).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (659).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (66).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (660).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (661).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (662).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (663).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (664).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (67).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (68).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (69).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (7).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (70).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (71).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (72).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (73).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (74).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (75).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (76).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (77).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (78).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (79).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (8).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (80).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (81).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (82).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (83).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (84).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (85).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (86).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (87).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (88).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (89).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (9).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (90).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (91).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (92).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (93).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (94).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (95).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (96).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (97).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (98).png
# D:\4TH YEAR\REserch\DATA SET\archive\data\vehicles\right (99).png

# %%
data_new=np.array(data) #Converting data into numpy array and renaming it to data_new
target_new=np.array(target) #Converting target into numpy array and renaming it to target_new
print(data_new.shape) #Get the shape of the data_new numpy array
print(target_new.shape) #Get the shape of the target_new numpy array
# Out:
# (17756, 64, 64)
# (17756,)

# %%
plt.imshow(data_new[123],cmap='gray') #Testing 123 image of the renamed array
print(target_new[123]) #Testing 123 image's class of the renamed array
# Out:
# 0

# %%
#np.save('data12345',data_new) #Saving data_new array 
#np.save('target12345',target_new) #Saving target new array


data = np.load('data12345.npy') #Load data_new array
target = np.load('target12345.npy') #Load target_new array

# %%
data_new  = np.array([feature.hog(im) for im in data])#extracting hog feature in every image in the data 


#data_new  = np.array([cv2.Canny(im,100,200) for im in data])
#data_new = data_new.reshape(17760,4096)


#knn  = cv2.getGaborKernel((5,5),3,1*np.pi/4,1*np.pi/4,0.5,0,ktype=cv2.CV_32F)

#data_new  = np.array([cv2.filter2D(im,cv2.CV_8UC3,knn) for im in data])
#data_new = data_new.reshape(17760,4096)






print(data_new.shape) #There were 17760 images in the array and 2916 features i ''
# Out:
# (17756, 2916)

# %%
train_data,test_data,train_target,test_target=train_test_split(data_new,target,test_size=0.1) #Splitting data from train set to test 
#trainx,testx,trainy,testy                                      x        y
print(train_data.shape) #Getting the size of each set
print(test_data.shape)
print(train_target.shape)
print(test_target.shape)
# Out:
# (15980, 2916)
# (1776, 2916)
# (15980,)
# (1776,)

# %%
import pandas as pd
import sklearn

from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.datasets import make_classification
from sklearn.svm import SVC

# %%
model = SVC(kernel='rbf') #Apply linear support vector machine to given data set to classify data into two categories
model.fit(train_data,train_target)
# Out:
# SVC()

# %%
predicted_target = model.predict(test_data) #Tesing accuracy in linear svm 

acc = accuracy_score(test_target,predicted_target)
print(acc)
# Out:
# 0.9876126126126126

# %%
matrix = confusion_matrix(test_target,predicted_target) #for the testing, getting the confusion matrix
print(matrix)
display = ConfusionMatrixDisplay(confusion_matrix=matrix,display_labels=['non-vehicle','vehicle'])
display.plot()
# Out:
# [[928   4]
#  [ 18 826]]

# %%
from sklearn.metrics import classification_report

print(classification_report(test_target,predicted_target,target_names=['vehicle', 'non-vehicle']))
# Out:
#               precision    recall  f1-score   support
#
#      vehicle       0.98      1.00      0.99       932
#  non-vehicle       1.00      0.98      0.99       844
#
#     accuracy                           0.99      1776
#    macro avg       0.99      0.99      0.99      1776
# weighted avg       0.99      0.99      0.99      1776

# %%
joblib.dump(model,'ML_Algo_VehicleDetection_SupportVector_rbf.sav')
# Out:
# ['ML_Algo_VehicleDetection_SupportVector_rbf.sav']

# %%
model = joblib.load('ML_Algo_VehicleDetection_SupportVector_rbf.sav')

# %%
def detect(img,h=64,w=64,slide=8): #Creating sliding window tecnique to identify images in selected image
    coordinates=[] #Define coordinated function 
    for y in range (0,img.shape[0]-h,slide): #Reduce hight from image shape
        for x in range(0,img.shape[1]-w,slide): #Reducing width form image shape
            window = img[y:y+h,x:x+w] #Getting a patch for identify the vehicles
            #print(patch.shape)
            hog_img = feature.hog(window) #Applying patch to hog feature which saved in vehicle detection model
            label=model.predict([hog_img]) #Applying predictions
            
            if(label==1):
                coordinates.append((x,y,w,h))
    return np.array(coordinates)

# %%
test_img = cv2.imread('dd.jpg') #Testing above sliding window tecnique to this test image test, dd, cc
test_img = cv2.resize(test_img,(256,256)) #Resizing the testing image
print(test_img.shape) #Get the image shape in tesing
plt.imshow(test_img,cmap='gray') #Show testing image
# Out:
# (256, 256, 3)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 4>()
#       2 test_img = cv2.resize(test_img,(256,256)) #Resizing the testing image
#       3 print(test_img.shape) #Get the image shape in tesing
# ----> 4 plt.imshow(test_img,cmap='gray')
#
# NameError: name 'plt' is not defined

# %%
gray = cv2.cvtColor(test_img,cv2.COLOR_BGR2GRAY) #Converting test image to GRAY
vehicle = detect(gray) #Apply detect function to image
for x,y,w,h in vehicle:
    
    cv2.rectangle(test_img,(x,y),(x+w,y+h),(0,255,0),1) #Apply rectangle to vehicles in the image
    
#cv2.imshow('test_image',test_img) #Show test image with rectangle
#cv2.waitKey(0) #Close window using ESC
#cv2.destroyAllWindows()
plt.imshow(test_img)

# %%
source = cv2.VideoCapture('aa.mp4') #Testing above method to a video tt

while(True): #Creating a loop to run above function in every frame    
    ret,img = source.read() #Getting frames from video    
    img = cv2.resize(img,(0,0),fx=0.2,fy=0.2) #Resizing
    
    if(ret==False): #Apply the above function to video same as the above test image
        break
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    vehicle = detect(gray)
    
    for x,y,w,h in vehicle:    
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),1)    
    cv2.imshow('img',img)
    k=cv2.waitKey(1)
    if(k==27):
        break

cv2.destroyAllWindows()
source.release()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [11], in <cell line: 4>()
#       3 while(True): #Creating a loop to run above function in every frame
#       4     ret,img = source.read() #Getting frames from video
# ----> 5     img = cv2.resize(img,(0,0),fx=0.2,fy=0.2) #Resizing
#       7     if(ret==False): #Apply the above function to video same as the above test image
#       8         break
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4052: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
SV_rbf
