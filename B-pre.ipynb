# %%
import os 
import numpy as np

data_path=r'dataset' #path for dataset

categories=os.listdir(data_path) #category types in the dataset

print(categories)
labels=np.arange(len(categories))
print(labels)
label_dict=dict(zip(categories,labels))
print(label_dict)
# Out:
# ['non-vehicles', 'vehicles']
# [0 1]
# {'non-vehicles': 0, 'vehicles': 1}

# %%
import cv2

img_size=64 #img size 100,100

test_data=[]
test_target=[]

for category in categories:
    
    imgs_path=os.path.join(data_path,category)
    img_names=os.listdir(imgs_path)
    #print(img_names)
    
    for img_name in img_names: #apply preprocessing to data in dataset
        
        img_path=os.path.join(imgs_path,img_name)
        print(img_path)
        try:
            img=cv2.imread(img_path)
            img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) #convert ti 
            img=cv2.resize(img,(img_size,img_size))
            test_data.append(img)
            test_target.append(label_dict[category])
        except Exception as e:
            print(img_path,e)
# Out:
# dataset\non-vehicles\extra1.png
# dataset\non-vehicles\extra10.png
# dataset\non-vehicles\extra100.png
# dataset\non-vehicles\extra1000.png
# dataset\non-vehicles\extra1001.png
# dataset\non-vehicles\extra1002.png
# dataset\non-vehicles\extra1003.png
# dataset\non-vehicles\extra1004.png
# dataset\non-vehicles\extra1005.png
# dataset\non-vehicles\extra1006.png
# dataset\non-vehicles\extra1007.png
# dataset\non-vehicles\extra1008.png
# dataset\non-vehicles\extra1009.png
# dataset\non-vehicles\extra101.png
# dataset\non-vehicles\extra1010.png
# dataset\non-vehicles\extra1011.png
# dataset\non-vehicles\extra1012.png
# dataset\non-vehicles\extra1013.png
# dataset\non-vehicles\extra1014.png
# dataset\non-vehicles\extra1015.png
# dataset\non-vehicles\extra102.png
# dataset\non-vehicles\extra103.png
# dataset\non-vehicles\extra1032.png
# dataset\non-vehicles\extra1033.png
# dataset\non-vehicles\extra1034.png
# dataset\non-vehicles\extra1035.png
# dataset\non-vehicles\extra1036.png
# dataset\non-vehicles\extra1037.png
# dataset\non-vehicles\extra1038.png
# dataset\non-vehicles\extra1039.png
# dataset\non-vehicles\extra104.png
# dataset\non-vehicles\extra1040.png
# dataset\non-vehicles\extra1041.png
# dataset\non-vehicles\extra1042.png
# dataset\non-vehicles\extra1043.png
# dataset\non-vehicles\extra1044.png
# dataset\non-vehicles\extra1045.png
# dataset\non-vehicles\extra1046.png
# dataset\non-vehicles\extra1047.png
# dataset\non-vehicles\extra1048.png
# dataset\non-vehicles\extra1049.png
# dataset\non-vehicles\extra105.png
# dataset\non-vehicles\extra1050.png
# dataset\non-vehicles\extra1051.png
# dataset\non-vehicles\extra1052.png
# dataset\non-vehicles\extra1053.png
# dataset\non-vehicles\extra1054.png
# dataset\non-vehicles\extra1055.png
# dataset\non-vehicles\extra1056.png
# dataset\non-vehicles\extra1057.png
# dataset\non-vehicles\extra1058.png
# dataset\non-vehicles\extra1059.png
# dataset\non-vehicles\extra106.png
# dataset\non-vehicles\extra1060.png
# dataset\non-vehicles\extra1061.png
# dataset\non-vehicles\extra1062.png
# dataset\non-vehicles\extra1063.png
# dataset\non-vehicles\extra1064.png
# dataset\non-vehicles\extra1065.png
# dataset\non-vehicles\extra1066.png
# dataset\non-vehicles\extra1067.png
# dataset\non-vehicles\extra1068.png
# dataset\non-vehicles\extra107.png
# dataset\non-vehicles\extra108.png
# dataset\non-vehicles\extra1089.png
# dataset\non-vehicles\extra109.png
# dataset\non-vehicles\extra1090.png
# dataset\non-vehicles\extra1091.png
# dataset\non-vehicles\extra1092.png
# dataset\non-vehicles\extra1093.png
# dataset\non-vehicles\extra1094.png
# dataset\non-vehicles\extra1095.png
# dataset\non-vehicles\extra1096.png
# dataset\non-vehicles\extra1097.png
# dataset\non-vehicles\extra1098.png
# dataset\non-vehicles\extra1099.png
# dataset\non-vehicles\extra11.png
# dataset\non-vehicles\extra110.png
# dataset\non-vehicles\extra1100.png
# dataset\non-vehicles\extra1101.png
# dataset\non-vehicles\extra1102.png
# dataset\non-vehicles\extra1103.png
# dataset\non-vehicles\extra1104.png
# dataset\non-vehicles\extra1105.png
# dataset\non-vehicles\extra1106.png
# dataset\non-vehicles\extra1107.png
# dataset\non-vehicles\extra1108.png
# dataset\non-vehicles\extra1109.png
# dataset\non-vehicles\extra1110.png
# dataset\non-vehicles\extra1111.png
# dataset\non-vehicles\extra1112.png
# dataset\non-vehicles\extra1113.png
# dataset\non-vehicles\extra1114.png
# dataset\non-vehicles\extra1115.png
# dataset\non-vehicles\extra1116.png
# dataset\non-vehicles\extra1117.png
# dataset\non-vehicles\extra1118.png
# dataset\non-vehicles\extra1119.png
# dataset\non-vehicles\extra112.png
# dataset\non-vehicles\extra1120.png
# dataset\non-vehicles\extra1121.png
# dataset\non-vehicles\extra1122.png
# dataset\non-vehicles\extra1123.png
# dataset\non-vehicles\extra1124.png
# dataset\non-vehicles\extra113.png
# dataset\non-vehicles\extra114.png
# dataset\non-vehicles\extra1146.png
# dataset\non-vehicles\extra1147.png
# dataset\non-vehicles\extra1148.png
# dataset\non-vehicles\extra1149.png
# dataset\non-vehicles\extra115.png
# dataset\non-vehicles\extra1150.png
# dataset\non-vehicles\extra1151.png
# dataset\non-vehicles\extra1152.png
# dataset\non-vehicles\extra1153.png
# dataset\non-vehicles\extra1154.png
# dataset\non-vehicles\extra1155.png
# dataset\non-vehicles\extra1156.png
# dataset\non-vehicles\extra1157.png
# dataset\non-vehicles\extra1158.png
# dataset\non-vehicles\extra1159.png
# dataset\non-vehicles\extra116.png
# dataset\non-vehicles\extra1160.png
# dataset\non-vehicles\extra1161.png
# dataset\non-vehicles\extra1162.png
# dataset\non-vehicles\extra1163.png
# dataset\non-vehicles\extra1164.png
# dataset\non-vehicles\extra1165.png
# dataset\non-vehicles\extra1166.png
# dataset\non-vehicles\extra1167.png
# dataset\non-vehicles\extra1168.png
# dataset\non-vehicles\extra1169.png
# dataset\non-vehicles\extra117.png
# dataset\non-vehicles\extra1170.png
# dataset\non-vehicles\extra1171.png
# dataset\non-vehicles\extra1172.png
# dataset\non-vehicles\extra1173.png
# dataset\non-vehicles\extra1174.png
# dataset\non-vehicles\extra1175.png
# dataset\non-vehicles\extra1176.png
# dataset\non-vehicles\extra1177.png
# dataset\non-vehicles\extra1178.png
# dataset\non-vehicles\extra1179.png
# dataset\non-vehicles\extra118.png
# dataset\non-vehicles\extra1180.png
# dataset\non-vehicles\extra119.png
# dataset\non-vehicles\extra12.png
# dataset\non-vehicles\extra120.png
# dataset\non-vehicles\extra1203.png
# dataset\non-vehicles\extra1204.png
# dataset\non-vehicles\extra1205.png
# dataset\non-vehicles\extra1206.png
# dataset\non-vehicles\extra1207.png
# dataset\non-vehicles\extra1208.png
# dataset\non-vehicles\extra1209.png
# dataset\non-vehicles\extra121.png
# dataset\non-vehicles\extra1210.png
# dataset\non-vehicles\extra1211.png
# dataset\non-vehicles\extra1212.png
# dataset\non-vehicles\extra1213.png
# dataset\non-vehicles\extra1214.png
# dataset\non-vehicles\extra1215.png
# dataset\non-vehicles\extra1216.png
# dataset\non-vehicles\extra1217.png
# dataset\non-vehicles\extra1218.png
# dataset\non-vehicles\extra1219.png
# dataset\non-vehicles\extra122.png
# dataset\non-vehicles\extra1220.png
# dataset\non-vehicles\extra1221.png
# dataset\non-vehicles\extra1222.png
# dataset\non-vehicles\extra1223.png
# dataset\non-vehicles\extra1224.png
# dataset\non-vehicles\extra1225.png
# dataset\non-vehicles\extra1226.png
# dataset\non-vehicles\extra1227.png
# dataset\non-vehicles\extra1228.png
# dataset\non-vehicles\extra1229.png
# dataset\non-vehicles\extra123.png
# dataset\non-vehicles\extra1230.png
# dataset\non-vehicles\extra1231.png
# dataset\non-vehicles\extra1232.png
# dataset\non-vehicles\extra1233.png
# dataset\non-vehicles\extra1234.png
# dataset\non-vehicles\extra1235.png
# dataset\non-vehicles\extra124.png
# dataset\non-vehicles\extra125.png
# dataset\non-vehicles\extra1258.png
# dataset\non-vehicles\extra1259.png
# dataset\non-vehicles\extra126.png
# dataset\non-vehicles\extra1260.png
# dataset\non-vehicles\extra1261.png
# dataset\non-vehicles\extra1262.png
# dataset\non-vehicles\extra1263.png
# dataset\non-vehicles\extra1264.png
# dataset\non-vehicles\extra1265.png
# dataset\non-vehicles\extra1266.png
# dataset\non-vehicles\extra1267.png
# dataset\non-vehicles\extra1268.png
# dataset\non-vehicles\extra1269.png
# dataset\non-vehicles\extra127.png
# dataset\non-vehicles\extra1270.png
# dataset\non-vehicles\extra1271.png
# dataset\non-vehicles\extra1272.png
# dataset\non-vehicles\extra1273.png
# dataset\non-vehicles\extra1274.png
# dataset\non-vehicles\extra1275.png
# dataset\non-vehicles\extra1276.png
# dataset\non-vehicles\extra1277.png
# dataset\non-vehicles\extra1278.png
# dataset\non-vehicles\extra1279.png
# dataset\non-vehicles\extra128.png
# dataset\non-vehicles\extra1280.png
# dataset\non-vehicles\extra1281.png
# dataset\non-vehicles\extra1282.png
# dataset\non-vehicles\extra1283.png
# dataset\non-vehicles\extra1284.png
# dataset\non-vehicles\extra1285.png
# dataset\non-vehicles\extra1286.png
# dataset\non-vehicles\extra1287.png
# dataset\non-vehicles\extra1288.png
# dataset\non-vehicles\extra1289.png
# dataset\non-vehicles\extra129.png
# dataset\non-vehicles\extra1290.png
# dataset\non-vehicles\extra1291.png
# dataset\non-vehicles\extra1292.png
# dataset\non-vehicles\extra1293.png
# dataset\non-vehicles\extra1294.png
# dataset\non-vehicles\extra1295.png
# dataset\non-vehicles\extra1296.png
# dataset\non-vehicles\extra1297.png
# dataset\non-vehicles\extra13.png
# dataset\non-vehicles\extra130.png
# dataset\non-vehicles\extra131.png
# dataset\non-vehicles\extra1315.png
# dataset\non-vehicles\extra1316.png
# dataset\non-vehicles\extra1317.png
# dataset\non-vehicles\extra1318.png
# dataset\non-vehicles\extra1319.png
# dataset\non-vehicles\extra132.png
# dataset\non-vehicles\extra1320.png
# dataset\non-vehicles\extra1321.png
# dataset\non-vehicles\extra1322.png
# dataset\non-vehicles\extra1323.png
# dataset\non-vehicles\extra1324.png
# dataset\non-vehicles\extra1325.png
# dataset\non-vehicles\extra1326.png
# dataset\non-vehicles\extra1327.png
# dataset\non-vehicles\extra1328.png
# dataset\non-vehicles\extra1329.png
# dataset\non-vehicles\extra133.png
# dataset\non-vehicles\extra1330.png
# dataset\non-vehicles\extra1331.png
# dataset\non-vehicles\extra1332.png
# dataset\non-vehicles\extra1333.png
# dataset\non-vehicles\extra1334.png
# dataset\non-vehicles\extra1335.png
# dataset\non-vehicles\extra1336.png
# dataset\non-vehicles\extra1337.png
# dataset\non-vehicles\extra1338.png
# dataset\non-vehicles\extra1339.png
# dataset\non-vehicles\extra134.png
# dataset\non-vehicles\extra1340.png
# dataset\non-vehicles\extra1341.png
# dataset\non-vehicles\extra1342.png
# dataset\non-vehicles\extra1343.png
# dataset\non-vehicles\extra1344.png
# dataset\non-vehicles\extra1345.png
# dataset\non-vehicles\extra1346.png
# dataset\non-vehicles\extra1347.png
# dataset\non-vehicles\extra1348.png
# dataset\non-vehicles\extra1349.png
# dataset\non-vehicles\extra135.png
# dataset\non-vehicles\extra1350.png
# dataset\non-vehicles\extra1351.png
# dataset\non-vehicles\extra1352.png
# dataset\non-vehicles\extra1353.png
# dataset\non-vehicles\extra1354.png
# dataset\non-vehicles\extra136.png
# dataset\non-vehicles\extra137.png
# dataset\non-vehicles\extra1373.png
# dataset\non-vehicles\extra1374.png
# dataset\non-vehicles\extra1375.png
# dataset\non-vehicles\extra1376.png
# dataset\non-vehicles\extra1377.png
# dataset\non-vehicles\extra1378.png
# dataset\non-vehicles\extra1379.png
# dataset\non-vehicles\extra138.png
# dataset\non-vehicles\extra1380.png
# dataset\non-vehicles\extra1381.png
# dataset\non-vehicles\extra1382.png
# dataset\non-vehicles\extra1383.png
# dataset\non-vehicles\extra1384.png
# dataset\non-vehicles\extra1385.png
# dataset\non-vehicles\extra1386.png
# dataset\non-vehicles\extra1387.png
# dataset\non-vehicles\extra1388.png
# dataset\non-vehicles\extra1389.png
# dataset\non-vehicles\extra139.png
# dataset\non-vehicles\extra1390.png
# dataset\non-vehicles\extra1391.png
# dataset\non-vehicles\extra1392.png
# dataset\non-vehicles\extra1393.png
# dataset\non-vehicles\extra1394.png
# dataset\non-vehicles\extra1395.png
# dataset\non-vehicles\extra1396.png
# dataset\non-vehicles\extra1397.png
# dataset\non-vehicles\extra1398.png
# dataset\non-vehicles\extra1399.png
# dataset\non-vehicles\extra14.png
# dataset\non-vehicles\extra140.png
# dataset\non-vehicles\extra1400.png
# dataset\non-vehicles\extra1401.png
# dataset\non-vehicles\extra1402.png
# dataset\non-vehicles\extra1403.png
# dataset\non-vehicles\extra1404.png
# dataset\non-vehicles\extra1405.png
# dataset\non-vehicles\extra1406.png
# dataset\non-vehicles\extra1407.png
# dataset\non-vehicles\extra1408.png
# dataset\non-vehicles\extra1409.png
# dataset\non-vehicles\extra141.png
# dataset\non-vehicles\extra1410.png
# dataset\non-vehicles\extra1411.png
# dataset\non-vehicles\extra1412.png
# dataset\non-vehicles\extra1413.png
# dataset\non-vehicles\extra1414.png
# dataset\non-vehicles\extra142.png
# dataset\non-vehicles\extra143.png
# dataset\non-vehicles\extra1431.png
# dataset\non-vehicles\extra1432.png
# dataset\non-vehicles\extra1433.png
# dataset\non-vehicles\extra1434.png
# dataset\non-vehicles\extra1435.png
# dataset\non-vehicles\extra1436.png
# dataset\non-vehicles\extra1437.png
# dataset\non-vehicles\extra1438.png
# dataset\non-vehicles\extra1439.png
# dataset\non-vehicles\extra144.png
# dataset\non-vehicles\extra1440.png
# dataset\non-vehicles\extra1441.png
# dataset\non-vehicles\extra1442.png
# dataset\non-vehicles\extra1443.png
# dataset\non-vehicles\extra1444.png
# dataset\non-vehicles\extra1445.png
# dataset\non-vehicles\extra1446.png
# dataset\non-vehicles\extra1447.png
# dataset\non-vehicles\extra1448.png
# dataset\non-vehicles\extra1449.png
# dataset\non-vehicles\extra145.png
# dataset\non-vehicles\extra1450.png
# dataset\non-vehicles\extra1451.png
# dataset\non-vehicles\extra1452.png
# dataset\non-vehicles\extra1453.png
# dataset\non-vehicles\extra1454.png
# dataset\non-vehicles\extra1455.png
# dataset\non-vehicles\extra1456.png
# dataset\non-vehicles\extra1457.png
# dataset\non-vehicles\extra1458.png
# dataset\non-vehicles\extra1459.png
# dataset\non-vehicles\extra146.png
# dataset\non-vehicles\extra1460.png
# dataset\non-vehicles\extra1461.png
# dataset\non-vehicles\extra1462.png
# dataset\non-vehicles\extra1463.png
# dataset\non-vehicles\extra1464.png
# dataset\non-vehicles\extra1465.png
# dataset\non-vehicles\extra1466.png
# dataset\non-vehicles\extra1467.png
# dataset\non-vehicles\extra1468.png
# dataset\non-vehicles\extra1469.png
# dataset\non-vehicles\extra147.png
# dataset\non-vehicles\extra1470.png
# dataset\non-vehicles\extra1471.png
# dataset\non-vehicles\extra1472.png
# dataset\non-vehicles\extra1473.png
# dataset\non-vehicles\extra1474.png
# dataset\non-vehicles\extra1475.png
# dataset\non-vehicles\extra1476.png
# dataset\non-vehicles\extra1477.png
# dataset\non-vehicles\extra148.png
# dataset\non-vehicles\extra149.png
# dataset\non-vehicles\extra1490.png
# dataset\non-vehicles\extra1491.png
# dataset\non-vehicles\extra1492.png
# dataset\non-vehicles\extra1493.png
# dataset\non-vehicles\extra1494.png
# dataset\non-vehicles\extra1495.png
# dataset\non-vehicles\extra1496.png
# dataset\non-vehicles\extra1497.png
# dataset\non-vehicles\extra1498.png
# dataset\non-vehicles\extra1499.png
# dataset\non-vehicles\extra15.png
# dataset\non-vehicles\extra150.png
# dataset\non-vehicles\extra1500.png
# dataset\non-vehicles\extra1501.png
# dataset\non-vehicles\extra1502.png
# dataset\non-vehicles\extra1503.png
# dataset\non-vehicles\extra1504.png
# dataset\non-vehicles\extra1505.png
# dataset\non-vehicles\extra1506.png
# dataset\non-vehicles\extra1507.png
# dataset\non-vehicles\extra1508.png
# dataset\non-vehicles\extra1509.png
# dataset\non-vehicles\extra151.png
# dataset\non-vehicles\extra1510.png
# dataset\non-vehicles\extra1511.png
# dataset\non-vehicles\extra1512.png
# dataset\non-vehicles\extra1513.png
# dataset\non-vehicles\extra1514.png
# dataset\non-vehicles\extra1515.png
# dataset\non-vehicles\extra1518.png
# dataset\non-vehicles\extra1519.png
# dataset\non-vehicles\extra152.png
# dataset\non-vehicles\extra1520.png
# dataset\non-vehicles\extra1521.png
# dataset\non-vehicles\extra1522.png
# dataset\non-vehicles\extra1523.png
# dataset\non-vehicles\extra1524.png
# dataset\non-vehicles\extra1525.png
# dataset\non-vehicles\extra1526.png
# dataset\non-vehicles\extra1527.png
# dataset\non-vehicles\extra1528.png
# dataset\non-vehicles\extra1529.png
# dataset\non-vehicles\extra153.png
# dataset\non-vehicles\extra1530.png
# dataset\non-vehicles\extra1531.png
# dataset\non-vehicles\extra1532.png
# dataset\non-vehicles\extra1533.png
# dataset\non-vehicles\extra1534.png
# dataset\non-vehicles\extra1535.png
# dataset\non-vehicles\extra1536.png
# dataset\non-vehicles\extra1537.png
# dataset\non-vehicles\extra1538.png
# dataset\non-vehicles\extra1539.png
# dataset\non-vehicles\extra154.png
# dataset\non-vehicles\extra1540.png
# dataset\non-vehicles\extra1541.png
# dataset\non-vehicles\extra155.png
# dataset\non-vehicles\extra1550.png
# dataset\non-vehicles\extra1551.png
# dataset\non-vehicles\extra1552.png
# dataset\non-vehicles\extra1553.png
# dataset\non-vehicles\extra1554.png
# dataset\non-vehicles\extra1555.png
# dataset\non-vehicles\extra1556.png
# dataset\non-vehicles\extra1557.png
# dataset\non-vehicles\extra1558.png
# dataset\non-vehicles\extra1559.png
# dataset\non-vehicles\extra156.png
# dataset\non-vehicles\extra1560.png
# dataset\non-vehicles\extra1561.png
# dataset\non-vehicles\extra1562.png
# dataset\non-vehicles\extra1563.png
# dataset\non-vehicles\extra1564.png
# dataset\non-vehicles\extra1565.png
# dataset\non-vehicles\extra1566.png
# dataset\non-vehicles\extra1567.png
# dataset\non-vehicles\extra1568.png
# dataset\non-vehicles\extra1569.png
# dataset\non-vehicles\extra157.png
# dataset\non-vehicles\extra1570.png
# dataset\non-vehicles\extra1571.png
# dataset\non-vehicles\extra1574.png
# dataset\non-vehicles\extra1575.png
# dataset\non-vehicles\extra1576.png
# dataset\non-vehicles\extra1577.png
# dataset\non-vehicles\extra1578.png
# dataset\non-vehicles\extra1579.png
# dataset\non-vehicles\extra158.png
# dataset\non-vehicles\extra1580.png
# dataset\non-vehicles\extra1581.png
# dataset\non-vehicles\extra1582.png
# dataset\non-vehicles\extra1583.png
# dataset\non-vehicles\extra1584.png
# dataset\non-vehicles\extra1585.png
# dataset\non-vehicles\extra1586.png
# dataset\non-vehicles\extra1587.png
# dataset\non-vehicles\extra1588.png
# dataset\non-vehicles\extra1589.png
# dataset\non-vehicles\extra159.png
# dataset\non-vehicles\extra1590.png
# dataset\non-vehicles\extra1591.png
# dataset\non-vehicles\extra1592.png
# dataset\non-vehicles\extra1593.png
# dataset\non-vehicles\extra1594.png
# dataset\non-vehicles\extra1595.png
# dataset\non-vehicles\extra1596.png
# dataset\non-vehicles\extra1597.png
# dataset\non-vehicles\extra1598.png
# dataset\non-vehicles\extra1599.png
# dataset\non-vehicles\extra16.png
# dataset\non-vehicles\extra160.png
# dataset\non-vehicles\extra1600.png
# dataset\non-vehicles\extra161.png
# dataset\non-vehicles\extra1610.png
# dataset\non-vehicles\extra1611.png
# dataset\non-vehicles\extra1612.png
# dataset\non-vehicles\extra1613.png
# dataset\non-vehicles\extra1614.png
# dataset\non-vehicles\extra1615.png
# dataset\non-vehicles\extra1616.png
# dataset\non-vehicles\extra1617.png
# dataset\non-vehicles\extra1618.png
# dataset\non-vehicles\extra1619.png
# dataset\non-vehicles\extra162.png
# dataset\non-vehicles\extra1620.png
# dataset\non-vehicles\extra1621.png
# dataset\non-vehicles\extra1622.png
# dataset\non-vehicles\extra1623.png
# dataset\non-vehicles\extra1624.png
# dataset\non-vehicles\extra1625.png
# dataset\non-vehicles\extra1626.png
# dataset\non-vehicles\extra1627.png
# dataset\non-vehicles\extra1628.png
# dataset\non-vehicles\extra1629.png
# dataset\non-vehicles\extra163.png
# dataset\non-vehicles\extra1630.png
# dataset\non-vehicles\extra1631.png
# dataset\non-vehicles\extra1632.png
# dataset\non-vehicles\extra1633.png
# dataset\non-vehicles\extra1634.png
# dataset\non-vehicles\extra1635.png
# dataset\non-vehicles\extra1636.png
# dataset\non-vehicles\extra1637.png
# dataset\non-vehicles\extra1638.png
# dataset\non-vehicles\extra1639.png
# dataset\non-vehicles\extra164.png
# dataset\non-vehicles\extra1640.png
# dataset\non-vehicles\extra1641.png
# dataset\non-vehicles\extra1642.png
# dataset\non-vehicles\extra1643.png
# dataset\non-vehicles\extra1644.png
# dataset\non-vehicles\extra1645.png
# dataset\non-vehicles\extra1646.png
# dataset\non-vehicles\extra1647.png
# dataset\non-vehicles\extra1648.png
# dataset\non-vehicles\extra1649.png
# dataset\non-vehicles\extra165.png
# dataset\non-vehicles\extra1650.png
# dataset\non-vehicles\extra1651.png
# dataset\non-vehicles\extra1652.png
# dataset\non-vehicles\extra1653.png
# dataset\non-vehicles\extra1654.png
# dataset\non-vehicles\extra1655.png
# dataset\non-vehicles\extra1656.png
# dataset\non-vehicles\extra1657.png
# dataset\non-vehicles\extra1658.png
# dataset\non-vehicles\extra1659.png
# dataset\non-vehicles\extra166.png
# dataset\non-vehicles\extra1660.png
# dataset\non-vehicles\extra1661.png
# dataset\non-vehicles\extra1662.png
# dataset\non-vehicles\extra1663.png
# dataset\non-vehicles\extra167.png
# dataset\non-vehicles\extra1670.png
# dataset\non-vehicles\extra1671.png
# dataset\non-vehicles\extra1672.png
# dataset\non-vehicles\extra1673.png
# dataset\non-vehicles\extra1674.png
# dataset\non-vehicles\extra1675.png
# dataset\non-vehicles\extra1676.png
# dataset\non-vehicles\extra1677.png
# dataset\non-vehicles\extra1678.png
# dataset\non-vehicles\extra1679.png
# dataset\non-vehicles\extra168.png
# dataset\non-vehicles\extra1680.png
# dataset\non-vehicles\extra1681.png
# dataset\non-vehicles\extra1682.png
# dataset\non-vehicles\extra1683.png
# dataset\non-vehicles\extra1684.png
# dataset\non-vehicles\extra1685.png
# dataset\non-vehicles\extra1686.png
# dataset\non-vehicles\extra1687.png
# dataset\non-vehicles\extra1688.png
# dataset\non-vehicles\extra1689.png
# dataset\non-vehicles\extra169.png
# dataset\non-vehicles\extra1690.png
# dataset\non-vehicles\extra1691.png
# dataset\non-vehicles\extra1694.png
# dataset\non-vehicles\extra1695.png
# dataset\non-vehicles\extra1697.png
# dataset\non-vehicles\extra1698.png
# dataset\non-vehicles\extra17.png
# dataset\non-vehicles\extra170.png
# dataset\non-vehicles\extra1700.png
# dataset\non-vehicles\extra1701.png
# dataset\non-vehicles\extra1704.png
# dataset\non-vehicles\extra1705.png
# dataset\non-vehicles\extra1706.png
# dataset\non-vehicles\extra1707.png
# dataset\non-vehicles\extra1709.png
# dataset\non-vehicles\extra171.png
# dataset\non-vehicles\extra1710.png
# dataset\non-vehicles\extra1711.png
# dataset\non-vehicles\extra1712.png
# dataset\non-vehicles\extra1713.png
# dataset\non-vehicles\extra1714.png
# dataset\non-vehicles\extra1715.png
# dataset\non-vehicles\extra1716.png
# dataset\non-vehicles\extra1717.png
# dataset\non-vehicles\extra1718.png
# dataset\non-vehicles\extra1719.png
# dataset\non-vehicles\extra172.png
# dataset\non-vehicles\extra1720.png
# dataset\non-vehicles\extra1721.png
# dataset\non-vehicles\extra1728.png
# dataset\non-vehicles\extra1729.png
# dataset\non-vehicles\extra173.png
# dataset\non-vehicles\extra1730.png
# dataset\non-vehicles\extra1731.png
# dataset\non-vehicles\extra1732.png
# dataset\non-vehicles\extra1733.png
# dataset\non-vehicles\extra1734.png
# dataset\non-vehicles\extra1735.png
# dataset\non-vehicles\extra1736.png
# dataset\non-vehicles\extra1737.png
# dataset\non-vehicles\extra1738.png
# dataset\non-vehicles\extra1739.png
# dataset\non-vehicles\extra174.png
# dataset\non-vehicles\extra1740.png
# dataset\non-vehicles\extra1741.png
# dataset\non-vehicles\extra1742.png
# dataset\non-vehicles\extra1743.png
# dataset\non-vehicles\extra1744.png
# dataset\non-vehicles\extra1745.png
# dataset\non-vehicles\extra1748.png
# dataset\non-vehicles\extra1749.png
# dataset\non-vehicles\extra175.png
# dataset\non-vehicles\extra1750.png
# dataset\non-vehicles\extra1753.png
# dataset\non-vehicles\extra1754.png
# dataset\non-vehicles\extra1756.png
# dataset\non-vehicles\extra1757.png
# dataset\non-vehicles\extra1759.png
# dataset\non-vehicles\extra176.png
# dataset\non-vehicles\extra1760.png
# dataset\non-vehicles\extra1761.png
# dataset\non-vehicles\extra1762.png
# dataset\non-vehicles\extra1764.png
# dataset\non-vehicles\extra1765.png
# dataset\non-vehicles\extra1766.png
# dataset\non-vehicles\extra1767.png
# dataset\non-vehicles\extra1768.png
# dataset\non-vehicles\extra1769.png
# dataset\non-vehicles\extra177.png
# dataset\non-vehicles\extra1770.png
# dataset\non-vehicles\extra1772.png
# dataset\non-vehicles\extra1773.png
# dataset\non-vehicles\extra1774.png
# dataset\non-vehicles\extra1775.png
# dataset\non-vehicles\extra1776.png
# dataset\non-vehicles\extra1777.png
# dataset\non-vehicles\extra1778.png
# dataset\non-vehicles\extra1779.png
# dataset\non-vehicles\extra178.png
# dataset\non-vehicles\extra1780.png
# dataset\non-vehicles\extra1781.png
# dataset\non-vehicles\extra1782.png
# dataset\non-vehicles\extra1783.png
# dataset\non-vehicles\extra1784.png
# dataset\non-vehicles\extra1785.png
# dataset\non-vehicles\extra1786.png
# dataset\non-vehicles\extra1787.png
# dataset\non-vehicles\extra1788.png
# dataset\non-vehicles\extra1789.png
# dataset\non-vehicles\extra179.png
# dataset\non-vehicles\extra1790.png
# dataset\non-vehicles\extra1791.png
# dataset\non-vehicles\extra1792.png
# dataset\non-vehicles\extra1793.png
# dataset\non-vehicles\extra1794.png
# dataset\non-vehicles\extra1795.png
# dataset\non-vehicles\extra1796.png
# dataset\non-vehicles\extra1797.png
# dataset\non-vehicles\extra1798.png
# dataset\non-vehicles\extra1799.png
# dataset\non-vehicles\extra18.png
# dataset\non-vehicles\extra180.png
# dataset\non-vehicles\extra1800.png
# dataset\non-vehicles\extra1803.png
# dataset\non-vehicles\extra1804.png
# dataset\non-vehicles\extra1806.png
# dataset\non-vehicles\extra1807.png
# dataset\non-vehicles\extra1809.png
# dataset\non-vehicles\extra181.png
# dataset\non-vehicles\extra1810.png
# dataset\non-vehicles\extra1812.png
# dataset\non-vehicles\extra1813.png
# dataset\non-vehicles\extra1815.png
# dataset\non-vehicles\extra1816.png
# dataset\non-vehicles\extra1817.png
# dataset\non-vehicles\extra1818.png
# dataset\non-vehicles\extra1819.png
# dataset\non-vehicles\extra182.png
# dataset\non-vehicles\extra1820.png
# dataset\non-vehicles\extra1821.png
# dataset\non-vehicles\extra1822.png
# dataset\non-vehicles\extra1823.png
# dataset\non-vehicles\extra1824.png
# dataset\non-vehicles\extra1825.png
# dataset\non-vehicles\extra183.png
# dataset\non-vehicles\extra1839.png
# dataset\non-vehicles\extra184.png
# dataset\non-vehicles\extra1840.png
# dataset\non-vehicles\extra1841.png
# dataset\non-vehicles\extra1842.png
# dataset\non-vehicles\extra1843.png
# dataset\non-vehicles\extra1844.png
# dataset\non-vehicles\extra1845.png
# dataset\non-vehicles\extra1846.png
# dataset\non-vehicles\extra1847.png
# dataset\non-vehicles\extra1848.png
# dataset\non-vehicles\extra1849.png
# dataset\non-vehicles\extra185.png
# dataset\non-vehicles\extra1850.png
# dataset\non-vehicles\extra1851.png
# dataset\non-vehicles\extra1852.png
# dataset\non-vehicles\extra1853.png
# dataset\non-vehicles\extra1854.png
# dataset\non-vehicles\extra1855.png
# dataset\non-vehicles\extra1856.png
# dataset\non-vehicles\extra1859.png
# dataset\non-vehicles\extra186.png
# dataset\non-vehicles\extra1860.png
# dataset\non-vehicles\extra1862.png
# dataset\non-vehicles\extra1863.png
# dataset\non-vehicles\extra1865.png
# dataset\non-vehicles\extra1866.png
# dataset\non-vehicles\extra1868.png
# dataset\non-vehicles\extra1869.png
# dataset\non-vehicles\extra187.png
# dataset\non-vehicles\extra1872.png
# dataset\non-vehicles\extra1873.png
# dataset\non-vehicles\extra1874.png
# dataset\non-vehicles\extra1875.png
# dataset\non-vehicles\extra1876.png
# dataset\non-vehicles\extra1877.png
# dataset\non-vehicles\extra1878.png
# dataset\non-vehicles\extra188.png
# dataset\non-vehicles\extra1884.png
# dataset\non-vehicles\extra1886.png
# dataset\non-vehicles\extra1887.png
# dataset\non-vehicles\extra1888.png
# dataset\non-vehicles\extra1889.png
# dataset\non-vehicles\extra189.png
# dataset\non-vehicles\extra1890.png
# dataset\non-vehicles\extra1891.png
# dataset\non-vehicles\extra1892.png
# dataset\non-vehicles\extra1893.png
# dataset\non-vehicles\extra1894.png
# dataset\non-vehicles\extra1895.png
# dataset\non-vehicles\extra1896.png
# dataset\non-vehicles\extra1897.png
# dataset\non-vehicles\extra1898.png
# dataset\non-vehicles\extra1899.png
# dataset\non-vehicles\extra19.png
# dataset\non-vehicles\extra190.png
# dataset\non-vehicles\extra1900.png
# dataset\non-vehicles\extra1901.png
# dataset\non-vehicles\extra1902.png
# dataset\non-vehicles\extra1903.png
# dataset\non-vehicles\extra1904.png
# dataset\non-vehicles\extra1905.png
# dataset\non-vehicles\extra1906.png
# dataset\non-vehicles\extra1907.png
# dataset\non-vehicles\extra1908.png
# dataset\non-vehicles\extra1909.png
# dataset\non-vehicles\extra191.png
# dataset\non-vehicles\extra1910.png
# dataset\non-vehicles\extra1911.png
# dataset\non-vehicles\extra1912.png
# dataset\non-vehicles\extra1913.png
# dataset\non-vehicles\extra1914.png
# dataset\non-vehicles\extra1915.png
# dataset\non-vehicles\extra1916.png
# dataset\non-vehicles\extra1917.png
# dataset\non-vehicles\extra1918.png
# dataset\non-vehicles\extra1919.png
# dataset\non-vehicles\extra192.png
# dataset\non-vehicles\extra1920.png
# dataset\non-vehicles\extra1921.png
# dataset\non-vehicles\extra1924.png
# dataset\non-vehicles\extra1925.png
# dataset\non-vehicles\extra1927.png
# dataset\non-vehicles\extra1928.png
# dataset\non-vehicles\extra193.png
# dataset\non-vehicles\extra1930.png
# dataset\non-vehicles\extra1931.png
# dataset\non-vehicles\extra1934.png
# dataset\non-vehicles\extra1937.png
# dataset\non-vehicles\extra1938.png
# dataset\non-vehicles\extra1939.png
# dataset\non-vehicles\extra194.png
# dataset\non-vehicles\extra1940.png
# dataset\non-vehicles\extra1941.png
# dataset\non-vehicles\extra1942.png
# dataset\non-vehicles\extra1943.png
# dataset\non-vehicles\extra195.png
# dataset\non-vehicles\extra1952.png
# dataset\non-vehicles\extra1953.png
# dataset\non-vehicles\extra1954.png
# dataset\non-vehicles\extra1955.png
# dataset\non-vehicles\extra1956.png
# dataset\non-vehicles\extra1957.png
# dataset\non-vehicles\extra1958.png
# dataset\non-vehicles\extra1959.png
# dataset\non-vehicles\extra196.png
# dataset\non-vehicles\extra1960.png
# dataset\non-vehicles\extra1961.png
# dataset\non-vehicles\extra1962.png
# dataset\non-vehicles\extra1963.png
# dataset\non-vehicles\extra1964.png
# dataset\non-vehicles\extra1965.png
# dataset\non-vehicles\extra1966.png
# dataset\non-vehicles\extra1967.png
# dataset\non-vehicles\extra1968.png
# dataset\non-vehicles\extra1969.png
# dataset\non-vehicles\extra197.png
# dataset\non-vehicles\extra1970.png
# dataset\non-vehicles\extra1971.png
# dataset\non-vehicles\extra1972.png
# dataset\non-vehicles\extra1973.png
# dataset\non-vehicles\extra1974.png
# dataset\non-vehicles\extra1975.png
# dataset\non-vehicles\extra1976.png
# dataset\non-vehicles\extra1977.png
# dataset\non-vehicles\extra1978.png
# dataset\non-vehicles\extra1979.png
# dataset\non-vehicles\extra198.png
# dataset\non-vehicles\extra1980.png
# dataset\non-vehicles\extra1981.png
# dataset\non-vehicles\extra1982.png
# dataset\non-vehicles\extra1983.png
# dataset\non-vehicles\extra1984.png
# dataset\non-vehicles\extra1985.png
# dataset\non-vehicles\extra1986.png
# dataset\non-vehicles\extra1987.png
# dataset\non-vehicles\extra1988.png
# dataset\non-vehicles\extra199.png
# dataset\non-vehicles\extra1991.png
# dataset\non-vehicles\extra1992.png
# dataset\non-vehicles\extra1995.png
# dataset\non-vehicles\extra1996.png
# dataset\non-vehicles\extra1999.png
# dataset\non-vehicles\extra2.png
# dataset\non-vehicles\extra20.png
# dataset\non-vehicles\extra200.png
# dataset\non-vehicles\extra2001.png
# dataset\non-vehicles\extra2002.png
# dataset\non-vehicles\extra2005.png
# dataset\non-vehicles\extra2006.png
# dataset\non-vehicles\extra2007.png
# dataset\non-vehicles\extra2008.png
# dataset\non-vehicles\extra2009.png
# dataset\non-vehicles\extra201.png
# dataset\non-vehicles\extra202.png
# dataset\non-vehicles\extra2021.png
# dataset\non-vehicles\extra2023.png
# dataset\non-vehicles\extra2024.png
# dataset\non-vehicles\extra2025.png
# dataset\non-vehicles\extra2026.png
# dataset\non-vehicles\extra2027.png
# dataset\non-vehicles\extra2028.png
# dataset\non-vehicles\extra2029.png
# dataset\non-vehicles\extra203.png
# dataset\non-vehicles\extra2030.png
# dataset\non-vehicles\extra2031.png
# dataset\non-vehicles\extra2032.png
# dataset\non-vehicles\extra2033.png
# dataset\non-vehicles\extra2034.png
# dataset\non-vehicles\extra2035.png
# dataset\non-vehicles\extra2036.png
# dataset\non-vehicles\extra2037.png
# dataset\non-vehicles\extra2038.png
# dataset\non-vehicles\extra2039.png
# dataset\non-vehicles\extra204.png
# dataset\non-vehicles\extra2040.png
# dataset\non-vehicles\extra2041.png
# dataset\non-vehicles\extra2042.png
# dataset\non-vehicles\extra2043.png
# dataset\non-vehicles\extra2044.png
# dataset\non-vehicles\extra2045.png
# dataset\non-vehicles\extra2046.png
# dataset\non-vehicles\extra2047.png
# dataset\non-vehicles\extra2048.png
# dataset\non-vehicles\extra2049.png
# dataset\non-vehicles\extra205.png
# dataset\non-vehicles\extra2050.png
# dataset\non-vehicles\extra2051.png
# dataset\non-vehicles\extra2052.png
# dataset\non-vehicles\extra2053.png
# dataset\non-vehicles\extra2054.png
# dataset\non-vehicles\extra2055.png
# dataset\non-vehicles\extra2056.png
# dataset\non-vehicles\extra2057.png
# dataset\non-vehicles\extra2058.png
# dataset\non-vehicles\extra2059.png
# dataset\non-vehicles\extra206.png
# dataset\non-vehicles\extra2060.png
# dataset\non-vehicles\extra2061.png
# dataset\non-vehicles\extra2062.png
# dataset\non-vehicles\extra2063.png
# dataset\non-vehicles\extra2064.png
# dataset\non-vehicles\extra2065.png
# dataset\non-vehicles\extra2066.png
# dataset\non-vehicles\extra2067.png
# dataset\non-vehicles\extra2068.png
# dataset\non-vehicles\extra2069.png
# dataset\non-vehicles\extra207.png
# dataset\non-vehicles\extra2070.png
# dataset\non-vehicles\extra2071.png
# dataset\non-vehicles\extra2072.png
# dataset\non-vehicles\extra2073.png
# dataset\non-vehicles\extra2074.png
# dataset\non-vehicles\extra2075.png
# dataset\non-vehicles\extra2076.png
# dataset\non-vehicles\extra2077.png
# dataset\non-vehicles\extra2078.png
# dataset\non-vehicles\extra208.png
# dataset\non-vehicles\extra2082.png
# dataset\non-vehicles\extra2089.png
# dataset\non-vehicles\extra209.png
# dataset\non-vehicles\extra2090.png
# dataset\non-vehicles\extra2091.png
# dataset\non-vehicles\extra2092.png
# dataset\non-vehicles\extra2093.png
# dataset\non-vehicles\extra2094.png
# dataset\non-vehicles\extra2096.png
# dataset\non-vehicles\extra2097.png
# dataset\non-vehicles\extra2098.png
# dataset\non-vehicles\extra2099.png
# dataset\non-vehicles\extra21.png
# dataset\non-vehicles\extra210.png
# dataset\non-vehicles\extra2100.png
# dataset\non-vehicles\extra2101.png
# dataset\non-vehicles\extra2102.png
# dataset\non-vehicles\extra2103.png
# dataset\non-vehicles\extra2104.png
# dataset\non-vehicles\extra2105.png
# dataset\non-vehicles\extra2106.png
# dataset\non-vehicles\extra2107.png
# dataset\non-vehicles\extra2108.png
# dataset\non-vehicles\extra2109.png
# dataset\non-vehicles\extra211.png
# dataset\non-vehicles\extra2110.png
# dataset\non-vehicles\extra2111.png
# dataset\non-vehicles\extra2112.png
# dataset\non-vehicles\extra2113.png
# dataset\non-vehicles\extra2114.png
# dataset\non-vehicles\extra2115.png
# dataset\non-vehicles\extra2116.png
# dataset\non-vehicles\extra2117.png
# dataset\non-vehicles\extra2118.png
# dataset\non-vehicles\extra2119.png
# dataset\non-vehicles\extra212.png
# dataset\non-vehicles\extra2120.png
# dataset\non-vehicles\extra2121.png
# dataset\non-vehicles\extra2122.png
# dataset\non-vehicles\extra2123.png
# dataset\non-vehicles\extra2124.png
# dataset\non-vehicles\extra2125.png
# dataset\non-vehicles\extra2126.png
# dataset\non-vehicles\extra2127.png
# dataset\non-vehicles\extra2128.png
# dataset\non-vehicles\extra2129.png
# dataset\non-vehicles\extra213.png
# dataset\non-vehicles\extra2130.png
# dataset\non-vehicles\extra2131.png
# dataset\non-vehicles\extra2132.png
# dataset\non-vehicles\extra2133.png
# dataset\non-vehicles\extra2134.png
# dataset\non-vehicles\extra2135.png
# dataset\non-vehicles\extra2136.png
# dataset\non-vehicles\extra2137.png
# dataset\non-vehicles\extra2138.png
# dataset\non-vehicles\extra2139.png
# dataset\non-vehicles\extra214.png
# dataset\non-vehicles\extra2140.png
# dataset\non-vehicles\extra2141.png
# dataset\non-vehicles\extra2142.png
# dataset\non-vehicles\extra2143.png
# dataset\non-vehicles\extra2144.png
# dataset\non-vehicles\extra2145.png
# dataset\non-vehicles\extra2146.png
# dataset\non-vehicles\extra2147.png
# dataset\non-vehicles\extra2148.png
# dataset\non-vehicles\extra2149.png
# dataset\non-vehicles\extra215.png
# dataset\non-vehicles\extra2150.png
# dataset\non-vehicles\extra2151.png
# dataset\non-vehicles\extra2152.png
# dataset\non-vehicles\extra2153.png
# dataset\non-vehicles\extra2154.png
# dataset\non-vehicles\extra216.png
# dataset\non-vehicles\extra2161.png
# dataset\non-vehicles\extra2165.png
# dataset\non-vehicles\extra2169.png
# dataset\non-vehicles\extra217.png
# dataset\non-vehicles\extra2170.png
# dataset\non-vehicles\extra2171.png
# dataset\non-vehicles\extra2172.png
# dataset\non-vehicles\extra2173.png
# dataset\non-vehicles\extra2174.png
# dataset\non-vehicles\extra2175.png
# dataset\non-vehicles\extra2176.png
# dataset\non-vehicles\extra2177.png
# dataset\non-vehicles\extra2178.png
# dataset\non-vehicles\extra2179.png
# dataset\non-vehicles\extra218.png
# dataset\non-vehicles\extra2180.png
# dataset\non-vehicles\extra2181.png
# dataset\non-vehicles\extra2182.png
# dataset\non-vehicles\extra2183.png
# dataset\non-vehicles\extra2184.png
# dataset\non-vehicles\extra2185.png
# dataset\non-vehicles\extra2186.png
# dataset\non-vehicles\extra2187.png
# dataset\non-vehicles\extra2188.png
# dataset\non-vehicles\extra2189.png
# dataset\non-vehicles\extra219.png
# dataset\non-vehicles\extra2190.png
# dataset\non-vehicles\extra2191.png
# dataset\non-vehicles\extra2192.png
# dataset\non-vehicles\extra2193.png
# dataset\non-vehicles\extra2194.png
# dataset\non-vehicles\extra2195.png
# dataset\non-vehicles\extra2196.png
# dataset\non-vehicles\extra2197.png
# dataset\non-vehicles\extra2198.png
# dataset\non-vehicles\extra2199.png
# dataset\non-vehicles\extra22.png
# dataset\non-vehicles\extra220.png
# dataset\non-vehicles\extra2200.png
# dataset\non-vehicles\extra2201.png
# dataset\non-vehicles\extra2202.png
# dataset\non-vehicles\extra2203.png
# dataset\non-vehicles\extra2204.png
# dataset\non-vehicles\extra2205.png
# dataset\non-vehicles\extra2206.png
# dataset\non-vehicles\extra2207.png
# dataset\non-vehicles\extra2208.png
# dataset\non-vehicles\extra2209.png
# dataset\non-vehicles\extra221.png
# dataset\non-vehicles\extra2210.png
# dataset\non-vehicles\extra2211.png
# dataset\non-vehicles\extra2212.png
# dataset\non-vehicles\extra2213.png
# dataset\non-vehicles\extra2214.png
# dataset\non-vehicles\extra2215.png
# dataset\non-vehicles\extra2216.png
# dataset\non-vehicles\extra2217.png
# dataset\non-vehicles\extra2218.png
# dataset\non-vehicles\extra2219.png
# dataset\non-vehicles\extra222.png
# dataset\non-vehicles\extra2220.png
# dataset\non-vehicles\extra2221.png
# dataset\non-vehicles\extra2222.png
# dataset\non-vehicles\extra2223.png
# dataset\non-vehicles\extra2224.png
# dataset\non-vehicles\extra2225.png
# dataset\non-vehicles\extra2226.png
# dataset\non-vehicles\extra2227.png
# dataset\non-vehicles\extra2228.png
# dataset\non-vehicles\extra2229.png
# dataset\non-vehicles\extra223.png
# dataset\non-vehicles\extra2230.png
# dataset\non-vehicles\extra2231.png
# dataset\non-vehicles\extra2238.png
# dataset\non-vehicles\extra224.png
# dataset\non-vehicles\extra2242.png
# dataset\non-vehicles\extra2246.png
# dataset\non-vehicles\extra2247.png
# dataset\non-vehicles\extra2248.png
# dataset\non-vehicles\extra2249.png
# dataset\non-vehicles\extra225.png
# dataset\non-vehicles\extra2250.png
# dataset\non-vehicles\extra2251.png
# dataset\non-vehicles\extra2252.png
# dataset\non-vehicles\extra2253.png
# dataset\non-vehicles\extra2254.png
# dataset\non-vehicles\extra2255.png
# dataset\non-vehicles\extra2256.png
# dataset\non-vehicles\extra2257.png
# dataset\non-vehicles\extra2258.png
# dataset\non-vehicles\extra2259.png
# dataset\non-vehicles\extra226.png
# dataset\non-vehicles\extra2260.png
# dataset\non-vehicles\extra2261.png
# dataset\non-vehicles\extra2262.png
# dataset\non-vehicles\extra2263.png
# dataset\non-vehicles\extra2264.png
# dataset\non-vehicles\extra2265.png
# dataset\non-vehicles\extra2266.png
# dataset\non-vehicles\extra2267.png
# dataset\non-vehicles\extra2268.png
# dataset\non-vehicles\extra2269.png
# dataset\non-vehicles\extra227.png
# dataset\non-vehicles\extra2270.png
# dataset\non-vehicles\extra2271.png
# dataset\non-vehicles\extra2272.png
# dataset\non-vehicles\extra2273.png
# dataset\non-vehicles\extra2274.png
# dataset\non-vehicles\extra2275.png
# dataset\non-vehicles\extra2276.png
# dataset\non-vehicles\extra2277.png
# dataset\non-vehicles\extra2278.png
# dataset\non-vehicles\extra2279.png
# dataset\non-vehicles\extra228.png
# dataset\non-vehicles\extra2280.png
# dataset\non-vehicles\extra2281.png
# dataset\non-vehicles\extra2282.png
# dataset\non-vehicles\extra2283.png
# dataset\non-vehicles\extra2284.png
# dataset\non-vehicles\extra2285.png
# dataset\non-vehicles\extra2286.png
# dataset\non-vehicles\extra2287.png
# dataset\non-vehicles\extra2288.png
# dataset\non-vehicles\extra2289.png
# dataset\non-vehicles\extra229.png
# dataset\non-vehicles\extra2290.png
# dataset\non-vehicles\extra2291.png
# dataset\non-vehicles\extra2292.png
# dataset\non-vehicles\extra2293.png
# dataset\non-vehicles\extra2294.png
# dataset\non-vehicles\extra2295.png
# dataset\non-vehicles\extra2296.png
# dataset\non-vehicles\extra2297.png
# dataset\non-vehicles\extra2298.png
# dataset\non-vehicles\extra2299.png
# dataset\non-vehicles\extra23.png
# dataset\non-vehicles\extra230.png
# dataset\non-vehicles\extra2300.png
# dataset\non-vehicles\extra2301.png
# dataset\non-vehicles\extra2302.png
# dataset\non-vehicles\extra2306.png
# dataset\non-vehicles\extra231.png
# dataset\non-vehicles\extra2317.png
# dataset\non-vehicles\extra232.png
# dataset\non-vehicles\extra2321.png
# dataset\non-vehicles\extra2322.png
# dataset\non-vehicles\extra2323.png
# dataset\non-vehicles\extra2324.png
# dataset\non-vehicles\extra2325.png
# dataset\non-vehicles\extra2326.png
# dataset\non-vehicles\extra2327.png
# dataset\non-vehicles\extra2328.png
# dataset\non-vehicles\extra2329.png
# dataset\non-vehicles\extra233.png
# dataset\non-vehicles\extra2330.png
# dataset\non-vehicles\extra2331.png
# dataset\non-vehicles\extra2332.png
# dataset\non-vehicles\extra2333.png
# dataset\non-vehicles\extra2334.png
# dataset\non-vehicles\extra2335.png
# dataset\non-vehicles\extra2336.png
# dataset\non-vehicles\extra2337.png
# dataset\non-vehicles\extra2338.png
# dataset\non-vehicles\extra2339.png
# dataset\non-vehicles\extra234.png
# dataset\non-vehicles\extra2340.png
# dataset\non-vehicles\extra2341.png
# dataset\non-vehicles\extra2342.png
# dataset\non-vehicles\extra2343.png
# dataset\non-vehicles\extra2344.png
# dataset\non-vehicles\extra2345.png
# dataset\non-vehicles\extra2346.png
# dataset\non-vehicles\extra2347.png
# dataset\non-vehicles\extra2348.png
# dataset\non-vehicles\extra2349.png
# dataset\non-vehicles\extra235.png
# dataset\non-vehicles\extra2350.png
# dataset\non-vehicles\extra2351.png
# dataset\non-vehicles\extra2352.png
# dataset\non-vehicles\extra2353.png
# dataset\non-vehicles\extra2354.png
# dataset\non-vehicles\extra2355.png
# dataset\non-vehicles\extra2356.png
# dataset\non-vehicles\extra2357.png
# dataset\non-vehicles\extra2358.png
# dataset\non-vehicles\extra2359.png
# dataset\non-vehicles\extra236.png
# dataset\non-vehicles\extra2360.png
# dataset\non-vehicles\extra2361.png
# dataset\non-vehicles\extra2362.png
# dataset\non-vehicles\extra2363.png
# dataset\non-vehicles\extra2364.png
# dataset\non-vehicles\extra2365.png
# dataset\non-vehicles\extra2366.png
# dataset\non-vehicles\extra2367.png
# dataset\non-vehicles\extra2368.png
# dataset\non-vehicles\extra2369.png
# dataset\non-vehicles\extra237.png
# dataset\non-vehicles\extra2370.png
# dataset\non-vehicles\extra2371.png
# dataset\non-vehicles\extra2372.png
# dataset\non-vehicles\extra2373.png
# dataset\non-vehicles\extra2374.png
# dataset\non-vehicles\extra2375.png
# dataset\non-vehicles\extra2376.png
# dataset\non-vehicles\extra2377.png
# dataset\non-vehicles\extra2378.png
# dataset\non-vehicles\extra2379.png
# dataset\non-vehicles\extra238.png
# dataset\non-vehicles\extra2380.png
# dataset\non-vehicles\extra2381.png
# dataset\non-vehicles\extra239.png
# dataset\non-vehicles\extra2392.png
# dataset\non-vehicles\extra2396.png
# dataset\non-vehicles\extra2397.png
# dataset\non-vehicles\extra2398.png
# dataset\non-vehicles\extra2399.png
# dataset\non-vehicles\extra24.png
# dataset\non-vehicles\extra240.png
# dataset\non-vehicles\extra2400.png
# dataset\non-vehicles\extra2401.png
# dataset\non-vehicles\extra2402.png
# dataset\non-vehicles\extra2403.png
# dataset\non-vehicles\extra2404.png
# dataset\non-vehicles\extra2405.png
# dataset\non-vehicles\extra2406.png
# dataset\non-vehicles\extra2407.png
# dataset\non-vehicles\extra2408.png
# dataset\non-vehicles\extra2409.png
# dataset\non-vehicles\extra241.png
# dataset\non-vehicles\extra2410.png
# dataset\non-vehicles\extra2411.png
# dataset\non-vehicles\extra2412.png
# dataset\non-vehicles\extra2413.png
# dataset\non-vehicles\extra2414.png
# dataset\non-vehicles\extra2415.png
# dataset\non-vehicles\extra2416.png
# dataset\non-vehicles\extra2417.png
# dataset\non-vehicles\extra2418.png
# dataset\non-vehicles\extra2419.png
# dataset\non-vehicles\extra242.png
# dataset\non-vehicles\extra2420.png
# dataset\non-vehicles\extra2421.png
# dataset\non-vehicles\extra2422.png
# dataset\non-vehicles\extra2423.png
# dataset\non-vehicles\extra2424.png
# dataset\non-vehicles\extra2425.png
# dataset\non-vehicles\extra2426.png
# dataset\non-vehicles\extra2427.png
# dataset\non-vehicles\extra2428.png
# dataset\non-vehicles\extra2429.png
# dataset\non-vehicles\extra243.png
# dataset\non-vehicles\extra2430.png
# dataset\non-vehicles\extra2431.png
# dataset\non-vehicles\extra2432.png
# dataset\non-vehicles\extra2433.png
# dataset\non-vehicles\extra2434.png
# dataset\non-vehicles\extra2435.png
# dataset\non-vehicles\extra2436.png
# dataset\non-vehicles\extra2437.png
# dataset\non-vehicles\extra2438.png
# dataset\non-vehicles\extra2439.png
# dataset\non-vehicles\extra244.png
# dataset\non-vehicles\extra2440.png
# dataset\non-vehicles\extra2441.png
# dataset\non-vehicles\extra2442.png
# dataset\non-vehicles\extra2443.png
# dataset\non-vehicles\extra2444.png
# dataset\non-vehicles\extra2445.png
# dataset\non-vehicles\extra2446.png
# dataset\non-vehicles\extra2447.png
# dataset\non-vehicles\extra2448.png
# dataset\non-vehicles\extra2449.png
# dataset\non-vehicles\extra245.png
# dataset\non-vehicles\extra2450.png
# dataset\non-vehicles\extra2451.png
# dataset\non-vehicles\extra2452.png
# dataset\non-vehicles\extra2453.png
# dataset\non-vehicles\extra2454.png
# dataset\non-vehicles\extra2455.png
# dataset\non-vehicles\extra2456.png
# dataset\non-vehicles\extra2457.png
# dataset\non-vehicles\extra2458.png
# dataset\non-vehicles\extra2459.png
# dataset\non-vehicles\extra246.png
# dataset\non-vehicles\extra2460.png
# dataset\non-vehicles\extra2461.png
# dataset\non-vehicles\extra2462.png
# dataset\non-vehicles\extra2463.png
# dataset\non-vehicles\extra2464.png
# dataset\non-vehicles\extra2465.png
# dataset\non-vehicles\extra2466.png
# dataset\non-vehicles\extra2467.png
# dataset\non-vehicles\extra2468.png
# dataset\non-vehicles\extra2469.png
# dataset\non-vehicles\extra247.png
# dataset\non-vehicles\extra2470.png
# dataset\non-vehicles\extra2471.png
# dataset\non-vehicles\extra2472.png
# dataset\non-vehicles\extra2473.png
# dataset\non-vehicles\extra2474.png
# dataset\non-vehicles\extra2475.png
# dataset\non-vehicles\extra2476.png
# dataset\non-vehicles\extra2477.png
# dataset\non-vehicles\extra2478.png
# dataset\non-vehicles\extra2479.png
# dataset\non-vehicles\extra248.png
# dataset\non-vehicles\extra2480.png
# dataset\non-vehicles\extra2481.png
# dataset\non-vehicles\extra2482.png
# dataset\non-vehicles\extra2483.png
# dataset\non-vehicles\extra2484.png
# dataset\non-vehicles\extra2485.png
# dataset\non-vehicles\extra2486.png
# dataset\non-vehicles\extra2487.png
# dataset\non-vehicles\extra2488.png
# dataset\non-vehicles\extra2489.png
# dataset\non-vehicles\extra249.png
# dataset\non-vehicles\extra2490.png
# dataset\non-vehicles\extra2491.png
# dataset\non-vehicles\extra2492.png
# dataset\non-vehicles\extra2493.png
# dataset\non-vehicles\extra2494.png
# dataset\non-vehicles\extra2495.png
# dataset\non-vehicles\extra2496.png
# dataset\non-vehicles\extra2497.png
# dataset\non-vehicles\extra2498.png
# dataset\non-vehicles\extra2499.png
# dataset\non-vehicles\extra25.png
# dataset\non-vehicles\extra250.png
# dataset\non-vehicles\extra2500.png
# dataset\non-vehicles\extra2501.png
# dataset\non-vehicles\extra2502.png
# dataset\non-vehicles\extra2503.png
# dataset\non-vehicles\extra2504.png
# dataset\non-vehicles\extra2505.png
# dataset\non-vehicles\extra2506.png
# dataset\non-vehicles\extra2507.png
# dataset\non-vehicles\extra2508.png
# dataset\non-vehicles\extra2509.png
# dataset\non-vehicles\extra251.png
# dataset\non-vehicles\extra2510.png
# dataset\non-vehicles\extra2511.png
# dataset\non-vehicles\extra2512.png
# dataset\non-vehicles\extra2513.png
# dataset\non-vehicles\extra2514.png
# dataset\non-vehicles\extra2515.png
# dataset\non-vehicles\extra2516.png
# dataset\non-vehicles\extra2517.png
# dataset\non-vehicles\extra2518.png
# dataset\non-vehicles\extra2519.png
# dataset\non-vehicles\extra252.png
# dataset\non-vehicles\extra2520.png
# dataset\non-vehicles\extra2521.png
# dataset\non-vehicles\extra2522.png
# dataset\non-vehicles\extra2523.png
# dataset\non-vehicles\extra2524.png
# dataset\non-vehicles\extra2525.png
# dataset\non-vehicles\extra2526.png
# dataset\non-vehicles\extra2527.png
# dataset\non-vehicles\extra2528.png
# dataset\non-vehicles\extra2529.png
# dataset\non-vehicles\extra253.png
# dataset\non-vehicles\extra2530.png
# dataset\non-vehicles\extra2531.png
# dataset\non-vehicles\extra2532.png
# dataset\non-vehicles\extra2533.png
# dataset\non-vehicles\extra2534.png
# dataset\non-vehicles\extra2535.png
# dataset\non-vehicles\extra2536.png
# dataset\non-vehicles\extra2537.png
# dataset\non-vehicles\extra2538.png
# dataset\non-vehicles\extra2539.png
# dataset\non-vehicles\extra254.png
# dataset\non-vehicles\extra2540.png
# dataset\non-vehicles\extra2541.png
# dataset\non-vehicles\extra2542.png
# dataset\non-vehicles\extra2543.png
# dataset\non-vehicles\extra2544.png
# dataset\non-vehicles\extra2545.png
# dataset\non-vehicles\extra2546.png
# dataset\non-vehicles\extra2547.png
# ...
# dataset\vehicles\veh018485.png
# dataset\vehicles\veh018486.png
# dataset\vehicles\veh018487.png
# dataset\vehicles\veh018488.png
# dataset\vehicles\veh018489.png
# dataset\vehicles\veh018490.png
# dataset\vehicles\veh018491.png
# dataset\vehicles\veh018492.png
# dataset\vehicles\veh018493.png
# dataset\vehicles\veh018494.png
# dataset\vehicles\veh018495.png
# dataset\vehicles\veh018496.png
# dataset\vehicles\veh018497.png
# dataset\vehicles\veh018498.png
# dataset\vehicles\veh018499.png
# dataset\vehicles\veh018500.png
# dataset\vehicles\veh018501.png
# dataset\vehicles\veh018502.png
# dataset\vehicles\veh018503.png
# dataset\vehicles\veh018504.png
# dataset\vehicles\veh018505.png
# dataset\vehicles\veh018506.png
# dataset\vehicles\veh018507.png
# dataset\vehicles\veh018508.png
# dataset\vehicles\veh018509.png
# dataset\vehicles\veh018510.png
# dataset\vehicles\veh018511.png
# dataset\vehicles\veh018512.png
# dataset\vehicles\veh018513.png
# dataset\vehicles\veh018514.png
# dataset\vehicles\veh018515.png
# dataset\vehicles\veh018516.png
# dataset\vehicles\veh018517.png
# dataset\vehicles\veh018518.png
# dataset\vehicles\veh018519.png
# dataset\vehicles\veh018520.png
# dataset\vehicles\veh018521.png
# dataset\vehicles\veh018522.png
# dataset\vehicles\veh018523.png
# dataset\vehicles\veh018524.png
# dataset\vehicles\veh018525.png
# dataset\vehicles\veh018526.png
# dataset\vehicles\veh018527.png
# dataset\vehicles\veh018528.png
# dataset\vehicles\veh018529.png
# dataset\vehicles\veh018530.png
# dataset\vehicles\veh018531.png
# dataset\vehicles\veh018532.png
# dataset\vehicles\veh018533.png
# dataset\vehicles\veh018534.png
# dataset\vehicles\veh018535.png
# dataset\vehicles\veh018536.png
# dataset\vehicles\veh018537.png
# dataset\vehicles\veh018538.png
# dataset\vehicles\veh018539.png
# dataset\vehicles\veh018540.png
# dataset\vehicles\veh018541.png
# dataset\vehicles\veh018542.png
# dataset\vehicles\veh018543.png
# dataset\vehicles\veh018544.png
# dataset\vehicles\veh018545.png
# dataset\vehicles\veh018546.png
# dataset\vehicles\veh018547.png
# dataset\vehicles\veh018548.png
# dataset\vehicles\veh018549.png
# dataset\vehicles\veh018550.png
# dataset\vehicles\veh018551.png
# dataset\vehicles\veh018552.png
# dataset\vehicles\veh018553.png
# dataset\vehicles\veh018554.png
# dataset\vehicles\veh018555.png
# dataset\vehicles\veh018556.png
# dataset\vehicles\veh018557.png
# dataset\vehicles\veh018558.png
# dataset\vehicles\veh018559.png
# dataset\vehicles\veh018560.png
# dataset\vehicles\veh018561.png
# dataset\vehicles\veh018562.png
# dataset\vehicles\veh018563.png
# dataset\vehicles\veh018564.png
# dataset\vehicles\veh018565.png
# dataset\vehicles\veh018566.png
# dataset\vehicles\veh018567.png
# dataset\vehicles\veh018568.png
# dataset\vehicles\veh018569.png
# dataset\vehicles\veh018570.png
# dataset\vehicles\veh018571.png
# dataset\vehicles\veh018572.png
# dataset\vehicles\veh018573.png
# dataset\vehicles\veh018574.png
# dataset\vehicles\veh018575.png
# dataset\vehicles\veh018576.png
# dataset\vehicles\veh018577.png
# dataset\vehicles\veh018578.png
# dataset\vehicles\veh018579.png
# dataset\vehicles\veh018580.png
# dataset\vehicles\veh018581.png
# dataset\vehicles\veh018582.png
# dataset\vehicles\veh018583.png
# dataset\vehicles\veh018584.png
# dataset\vehicles\veh018585.png
# dataset\vehicles\veh018586.png
# dataset\vehicles\veh018587.png
# dataset\vehicles\veh018588.png
# dataset\vehicles\veh018589.png
# dataset\vehicles\veh018590.png
# dataset\vehicles\veh018591.png
# dataset\vehicles\veh018592.png
# dataset\vehicles\veh018593.png
# dataset\vehicles\veh018594.png
# dataset\vehicles\veh018595.png
# dataset\vehicles\veh018596.png
# dataset\vehicles\veh018597.png
# dataset\vehicles\veh018598.png
# dataset\vehicles\veh018599.png
# dataset\vehicles\veh018600.png
# dataset\vehicles\veh018601.png
# dataset\vehicles\veh018602.png
# dataset\vehicles\veh018603.png
# dataset\vehicles\veh018604.png
# dataset\vehicles\veh018605.png
# dataset\vehicles\veh018606.png
# dataset\vehicles\veh018607.png
# dataset\vehicles\veh018608.png
# dataset\vehicles\veh018609.png
# dataset\vehicles\veh018610.png
# dataset\vehicles\veh018611.png
# dataset\vehicles\veh018612.png
# dataset\vehicles\veh018613.png
# dataset\vehicles\veh018614.png
# dataset\vehicles\veh018615.png
# dataset\vehicles\veh018616.png
# dataset\vehicles\veh018617.png
# dataset\vehicles\veh018618.png
# dataset\vehicles\veh018619.png
# dataset\vehicles\veh018620.png
# dataset\vehicles\veh018621.png
# dataset\vehicles\veh018622.png
# dataset\vehicles\veh018623.png
# dataset\vehicles\veh018624.png
# dataset\vehicles\veh018625.png
# dataset\vehicles\veh018626.png
# dataset\vehicles\veh018627.png
# dataset\vehicles\veh018628.png
# dataset\vehicles\veh018629.png
# dataset\vehicles\veh018630.png
# dataset\vehicles\veh018631.png
# dataset\vehicles\veh018632.png
# dataset\vehicles\veh018633.png
# dataset\vehicles\veh018634.png
# dataset\vehicles\veh018635.png
# dataset\vehicles\veh018636.png
# dataset\vehicles\veh018637.png
# dataset\vehicles\veh018638.png
# dataset\vehicles\veh018639.png
# dataset\vehicles\veh018640.png
# dataset\vehicles\veh018641.png
# dataset\vehicles\veh018642.png
# dataset\vehicles\veh018643.png
# dataset\vehicles\veh018644.png
# dataset\vehicles\veh018645.png
# dataset\vehicles\veh018646.png
# dataset\vehicles\veh018647.png
# dataset\vehicles\veh018648.png
# dataset\vehicles\veh018649.png
# dataset\vehicles\veh018650.png
# dataset\vehicles\veh018651.png
# dataset\vehicles\veh018652.png
# dataset\vehicles\veh018653.png
# dataset\vehicles\veh018654.png
# dataset\vehicles\veh018655.png
# dataset\vehicles\veh018656.png
# dataset\vehicles\veh018657.png
# dataset\vehicles\veh018658.png
# dataset\vehicles\veh018659.png
# dataset\vehicles\veh018660.png
# dataset\vehicles\veh018661.png
# dataset\vehicles\veh018662.png
# dataset\vehicles\veh018663.png
# dataset\vehicles\veh018664.png
# dataset\vehicles\veh018665.png
# dataset\vehicles\veh018666.png
# dataset\vehicles\veh018667.png
# dataset\vehicles\veh018668.png
# dataset\vehicles\veh018669.png
# dataset\vehicles\veh018670.png
# dataset\vehicles\veh018671.png
# dataset\vehicles\veh018672.png
# dataset\vehicles\veh018673.png
# dataset\vehicles\veh018674.png
# dataset\vehicles\veh018675.png
# dataset\vehicles\veh018676.png
# dataset\vehicles\veh018677.png
# dataset\vehicles\veh018678.png
# dataset\vehicles\veh018679.png
# dataset\vehicles\veh018680.png
# dataset\vehicles\veh018681.png
# dataset\vehicles\veh018682.png
# dataset\vehicles\veh018683.png
# dataset\vehicles\veh018684.png
# dataset\vehicles\veh018685.png
# dataset\vehicles\veh018686.png
# dataset\vehicles\veh018687.png
# dataset\vehicles\veh018688.png
# dataset\vehicles\veh018689.png
# dataset\vehicles\veh018690.png
# dataset\vehicles\veh018691.png
# dataset\vehicles\veh018692.png
# dataset\vehicles\veh018693.png
# dataset\vehicles\veh018694.png
# dataset\vehicles\veh018695.png
# dataset\vehicles\veh018696.png
# dataset\vehicles\veh018697.png
# dataset\vehicles\veh018698.png
# dataset\vehicles\veh018699.png
# dataset\vehicles\veh018700.png
# dataset\vehicles\veh018701.png
# dataset\vehicles\veh018702.png
# dataset\vehicles\veh018703.png
# dataset\vehicles\veh018704.png
# dataset\vehicles\veh018705.png
# dataset\vehicles\veh018706.png
# dataset\vehicles\veh018707.png
# dataset\vehicles\veh018708.png
# dataset\vehicles\veh018709.png
# dataset\vehicles\veh018710.png
# dataset\vehicles\veh018711.png
# dataset\vehicles\veh018712.png
# dataset\vehicles\veh018713.png
# dataset\vehicles\veh018714.png
# dataset\vehicles\veh018715.png
# dataset\vehicles\veh018716.png
# dataset\vehicles\veh018717.png
# dataset\vehicles\veh018718.png
# dataset\vehicles\veh018719.png
# dataset\vehicles\veh018720.png
# dataset\vehicles\veh018721.png
# dataset\vehicles\veh018722.png
# dataset\vehicles\veh018723.png
# dataset\vehicles\veh018724.png
# dataset\vehicles\veh018725.png
# dataset\vehicles\veh018726.png
# dataset\vehicles\veh018727.png
# dataset\vehicles\veh018728.png
# dataset\vehicles\veh018729.png
# dataset\vehicles\veh018730.png
# dataset\vehicles\veh018731.png
# dataset\vehicles\veh018732.png
# dataset\vehicles\veh018733.png
# dataset\vehicles\veh018734.png
# dataset\vehicles\veh018735.png
# dataset\vehicles\veh018736.png
# dataset\vehicles\veh018737.png
# dataset\vehicles\veh018738.png
# dataset\vehicles\veh018739.png
# dataset\vehicles\veh018740.png
# dataset\vehicles\veh018741.png
# dataset\vehicles\veh018742.png
# dataset\vehicles\veh018743.png
# dataset\vehicles\veh018744.png
# dataset\vehicles\veh018745.png
# dataset\vehicles\veh018746.png
# dataset\vehicles\veh018747.png
# dataset\vehicles\veh018748.png
# dataset\vehicles\veh018749.png
# dataset\vehicles\veh018750.png
# dataset\vehicles\veh018751.png
# dataset\vehicles\veh018752.png
# dataset\vehicles\veh018753.png
# dataset\vehicles\veh018754.png
# dataset\vehicles\veh018755.png
# dataset\vehicles\veh018756.png
# dataset\vehicles\veh018757.png
# dataset\vehicles\veh018758.png
# dataset\vehicles\veh018759.png
# dataset\vehicles\veh018760.png
# dataset\vehicles\veh018761.png
# dataset\vehicles\veh018762.png
# dataset\vehicles\veh018763.png
# dataset\vehicles\veh018764.png
# dataset\vehicles\veh018765.png
# dataset\vehicles\veh018766.png
# dataset\vehicles\veh018767.png
# dataset\vehicles\veh018768.png
# dataset\vehicles\veh018769.png
# dataset\vehicles\veh018770.png
# dataset\vehicles\veh018771.png
# dataset\vehicles\veh018772.png
# dataset\vehicles\veh018773.png
# dataset\vehicles\veh018774.png
# dataset\vehicles\veh018775.png
# dataset\vehicles\veh018776.png
# dataset\vehicles\veh018777.png
# dataset\vehicles\veh018778.png
# dataset\vehicles\veh018779.png
# dataset\vehicles\veh018780.png
# dataset\vehicles\veh018781.png
# dataset\vehicles\veh018782.png
# dataset\vehicles\veh018783.png
# dataset\vehicles\veh018784.png
# dataset\vehicles\veh018785.png
# dataset\vehicles\veh018786.png
# dataset\vehicles\veh018787.png
# dataset\vehicles\veh018788.png
# dataset\vehicles\veh018789.png
# dataset\vehicles\veh018790.png
# dataset\vehicles\veh018791.png
# dataset\vehicles\veh018792.png
# dataset\vehicles\veh018793.png
# dataset\vehicles\veh018794.png
# dataset\vehicles\veh018795.png
# dataset\vehicles\veh018796.png
# dataset\vehicles\veh018797.png
# dataset\vehicles\veh018798.png
# dataset\vehicles\veh018799.png
# dataset\vehicles\veh018800.png
# dataset\vehicles\veh018801.png
# dataset\vehicles\veh018802.png
# dataset\vehicles\veh018803.png
# dataset\vehicles\veh018804.png
# dataset\vehicles\veh018805.png
# dataset\vehicles\veh018806.png
# dataset\vehicles\veh018807.png
# dataset\vehicles\veh018808.png
# dataset\vehicles\veh018809.png
# dataset\vehicles\veh018810.png
# dataset\vehicles\veh018811.png
# dataset\vehicles\veh018812.png
# dataset\vehicles\veh018813.png
# dataset\vehicles\veh018814.png
# dataset\vehicles\veh018815.png
# dataset\vehicles\veh018816.png
# dataset\vehicles\veh018817.png
# dataset\vehicles\veh018818.png
# dataset\vehicles\veh018819.png
# dataset\vehicles\veh018820.png
# dataset\vehicles\veh018821.png
# dataset\vehicles\veh018822.png
# dataset\vehicles\veh018823.png
# dataset\vehicles\veh018824.png
# dataset\vehicles\veh018825.png
# dataset\vehicles\veh018826.png
# dataset\vehicles\veh018827.png
# dataset\vehicles\veh018828.png
# dataset\vehicles\veh018829.png
# dataset\vehicles\veh018830.png
# dataset\vehicles\veh018831.png
# dataset\vehicles\veh018832.png
# dataset\vehicles\veh018833.png
# dataset\vehicles\veh018834.png
# dataset\vehicles\veh018835.png
# dataset\vehicles\veh018836.png
# dataset\vehicles\veh018837.png
# dataset\vehicles\veh018838.png
# dataset\vehicles\veh018839.png
# dataset\vehicles\veh018840.png
# dataset\vehicles\veh018841.png
# dataset\vehicles\veh018842.png
# dataset\vehicles\veh018843.png
# dataset\vehicles\veh018844.png
# dataset\vehicles\veh018845.png
# dataset\vehicles\veh018846.png
# dataset\vehicles\veh018847.png
# dataset\vehicles\veh018848.png
# dataset\vehicles\veh018849.png
# dataset\vehicles\veh018850.png
# dataset\vehicles\veh018851.png
# dataset\vehicles\veh018852.png
# dataset\vehicles\veh018853.png
# dataset\vehicles\veh018854.png
# dataset\vehicles\veh018855.png
# dataset\vehicles\veh018856.png
# dataset\vehicles\veh018857.png
# dataset\vehicles\veh018858.png
# dataset\vehicles\veh018859.png
# dataset\vehicles\veh018860.png
# dataset\vehicles\veh018861.png
# dataset\vehicles\veh018862.png
# dataset\vehicles\veh018863.png
# dataset\vehicles\veh018864.png
# dataset\vehicles\veh018865.png
# dataset\vehicles\veh018866.png
# dataset\vehicles\veh018867.png
# dataset\vehicles\veh018868.png
# dataset\vehicles\veh018869.png
# dataset\vehicles\veh018870.png
# dataset\vehicles\veh018871.png
# dataset\vehicles\veh018872.png
# dataset\vehicles\veh018873.png
# dataset\vehicles\veh018874.png
# dataset\vehicles\veh018875.png
# dataset\vehicles\veh018876.png
# dataset\vehicles\veh018877.png
# dataset\vehicles\veh018878.png
# dataset\vehicles\veh018879.png
# dataset\vehicles\veh018880.png
# dataset\vehicles\veh018881.png
# dataset\vehicles\veh018882.png
# dataset\vehicles\veh018883.png
# dataset\vehicles\veh018884.png
# dataset\vehicles\veh018885.png
# dataset\vehicles\veh018886.png
# dataset\vehicles\veh018887.png
# dataset\vehicles\veh018888.png
# dataset\vehicles\veh018889.png
# dataset\vehicles\veh018890.png
# dataset\vehicles\veh018891.png
# dataset\vehicles\veh018892.png
# dataset\vehicles\veh018893.png
# dataset\vehicles\veh018894.png
# dataset\vehicles\veh018895.png
# dataset\vehicles\veh018896.png
# dataset\vehicles\veh018897.png
# dataset\vehicles\veh018898.png
# dataset\vehicles\veh018899.png
# dataset\vehicles\veh018900.png
# dataset\vehicles\veh018901.png
# dataset\vehicles\veh018902.png
# dataset\vehicles\veh018903.png
# dataset\vehicles\veh018904.png
# dataset\vehicles\veh018905.png
# dataset\vehicles\veh018906.png
# dataset\vehicles\veh018907.png
# dataset\vehicles\veh018908.png
# dataset\vehicles\veh018909.png
# dataset\vehicles\veh018910.png
# dataset\vehicles\veh018911.png
# dataset\vehicles\veh018912.png
# dataset\vehicles\veh018913.png
# dataset\vehicles\veh018914.png
# dataset\vehicles\veh018915.png
# dataset\vehicles\veh018916.png
# dataset\vehicles\veh018917.png
# dataset\vehicles\veh018918.png
# dataset\vehicles\veh018919.png
# dataset\vehicles\veh018920.png
# dataset\vehicles\veh018921.png
# dataset\vehicles\veh018922.png
# dataset\vehicles\veh018923.png
# dataset\vehicles\veh018924.png
# dataset\vehicles\veh018925.png
# dataset\vehicles\veh018926.png
# dataset\vehicles\veh018927.png
# dataset\vehicles\veh018928.png
# dataset\vehicles\veh018929.png
# dataset\vehicles\veh018930.png
# dataset\vehicles\veh018931.png
# dataset\vehicles\veh018932.png
# dataset\vehicles\veh018933.png
# dataset\vehicles\veh018934.png
# dataset\vehicles\veh018935.png
# dataset\vehicles\veh018936.png
# dataset\vehicles\veh018937.png
# dataset\vehicles\veh018938.png
# dataset\vehicles\veh018939.png
# dataset\vehicles\veh018940.png
# dataset\vehicles\veh018941.png
# dataset\vehicles\veh018942.png
# dataset\vehicles\veh018943.png
# dataset\vehicles\veh018944.png
# dataset\vehicles\veh018945.png
# dataset\vehicles\veh018946.png
# dataset\vehicles\veh018947.png
# dataset\vehicles\veh018948.png
# dataset\vehicles\veh018949.png
# dataset\vehicles\veh018950.png
# dataset\vehicles\veh018951.png
# dataset\vehicles\veh018952.png
# dataset\vehicles\veh018953.png
# dataset\vehicles\veh018954.png
# dataset\vehicles\veh018955.png
# dataset\vehicles\veh018956.png
# dataset\vehicles\veh018957.png
# dataset\vehicles\veh018958.png
# dataset\vehicles\veh018959.png
# dataset\vehicles\veh018960.png
# dataset\vehicles\veh018961.png
# dataset\vehicles\veh018962.png
# dataset\vehicles\veh018963.png
# dataset\vehicles\veh018964.png
# dataset\vehicles\veh018965.png
# dataset\vehicles\veh018966.png
# dataset\vehicles\veh018967.png
# dataset\vehicles\veh018968.png
# dataset\vehicles\veh018969.png
# dataset\vehicles\veh018970.png
# dataset\vehicles\veh018971.png
# dataset\vehicles\veh018972.png
# dataset\vehicles\veh018973.png
# dataset\vehicles\veh018974.png
# dataset\vehicles\veh018975.png
# dataset\vehicles\veh018976.png
# dataset\vehicles\veh018977.png
# dataset\vehicles\veh018978.png
# dataset\vehicles\veh018979.png
# dataset\vehicles\veh018980.png
# dataset\vehicles\veh018981.png
# dataset\vehicles\veh018982.png
# dataset\vehicles\veh018983.png
# dataset\vehicles\veh018984.png
# dataset\vehicles\veh018985.png
# dataset\vehicles\veh018986.png
# dataset\vehicles\veh018987.png
# dataset\vehicles\veh018988.png
# dataset\vehicles\veh018989.png
# dataset\vehicles\veh018990.png
# dataset\vehicles\veh018991.png
# dataset\vehicles\veh018992.png
# dataset\vehicles\veh018993.png
# dataset\vehicles\veh018994.png
# dataset\vehicles\veh018995.png
# dataset\vehicles\veh018996.png
# dataset\vehicles\veh018997.png
# dataset\vehicles\veh018998.png
# dataset\vehicles\veh018999.png
# dataset\vehicles\veh019000.png

# %%
data_new=np.array(test_data)
target_new=np.array(test_target)

# %%
print(data_new.shape)
print(target_new.shape)
# Out:
# (55756, 64, 64)
# (55756,)

# %%
from matplotlib import pyplot as plt

plt.imshow(test_data[50],cmap='gray')

# %%
target_new[45]
# Out:
# 0

# %%
print(data_new.shape)
print(data_new.shape[0],data_new.shape[1],data_new.shape[2])
# Out:
# (55756, 64, 64)
# 55756 64 64

# %%
data_new=data_new.reshape(data_new.shape[0],data_new.shape[1],data_new.shape[2],1) # converting to 4D, CNN needs 4D input
print(data_new.shape)
# Out:
# (55756, 64, 64, 1)

# %%
data_new=data_new/255 #normalizing/ Scaling

from keras.utils import np_utils

target_new=np_utils.to_categorical(target_new)

# %%
np.save('test_data_B',data_new)
np.save('test_target_B',target_new)
